# %%
df = pd.read_csv("../data/processed/processed_crime.csv")

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=8, random_state=42)
df['Cluster_KMeans'] = kmeans.fit_predict(geo_scaled)

# %%
from sklearn.metrics import silhouette_score

score = silhouette_score(geo_scaled, df['Cluster_KMeans'])
print(score)

# %%
from sklearn.cluster import DBSCAN

db = DBSCAN(eps=0.03, min_samples=20)
df['Cluster_DBSCAN'] = db.fit_predict(geo_scaled)

# %%
from sklearn.cluster import AgglomerativeClustering

agg = AgglomerativeClustering(n_clusters=6)
df['Cluster_Hier'] = agg.fit_predict(geo_scaled)

# %%
temporal_features = df[['Hour','Month']]
